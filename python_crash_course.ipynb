# %% [markdown]
# # Python Crash Course
# A Hands-on, project-based, introduction to programming, by Eric Matthes

# %% [markdown]
# ## Part 1: Basics

# %% [markdown]
# ### Chapter 2: Variables and Simple Data Types

# %%
# hello_world.py

message = "Hello Python world!"
print(message)

message = "Hello Python Crash Course world!"
print(message)
# Out:
# Hello Python world!
# Hello Python Crash Course world!

# %% [markdown]
# ### Chapter 9: Classes

# %% [markdown]
# #### Creating and Using a Class

# %% [markdown]
# ##### Creating the Dog Class

# %%
# dog.py
class Dog:
    def __init__(self, name, age):
        """Initialize name and age attributes."""
        self.name = name
        self.age = age
    
    def sit(self):
        """Simulate a dog sitting in response to a command."""
        print(f"{self.name} is now sitting.")

    def roll_over(self):
        """Simulate rolling over in response to a command."""
        print(f"{self.name} rolled over!")

# %% [markdown]
# ##### Making an Instance from a Class

# %%
my_dog = Dog('Calma', 5)

print(f"My dog's name is {my_dog.name}.")
print(f"My dog is {my_dog.age} years old.")
# Out:
# My dog's name is Calma.
# My dog is 5 years old.

# %%
my_dog.sit()
my_dog.roll_over()
# Out:
# Calma is now sitting.
# Calma rolled over!

# %%
your_dog = Dog('Aufredo', 1)

print(f"Your dog's name is {your_dog.name}.")
print(f"Your dog is {your_dog.age} years old.")
your_dog.sit()
# Out:
# Your dog's name is Aufredo.
# Your dog is 1 years old.
# Aufredo is now sitting.

# %%
# 9-1 Restaurant
class Restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        """Initialize restaurant name and cuisine type."""
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
    
    def describe_restaurant(self):
        """Print a description of the restaurant."""
        print(f"{self.restaurant_name} serves {self.cuisine_type} cuisine.")

    def open_restaurant(self):
        """Print a message indicating that the restaurant is open."""
        print(f"{self.restaurant_name} is now open!")

restaurant = Restaurant('RR', 'morning food')
print(f"Restaurant name: {restaurant.restaurant_name}")
print(f"Cuisine type: {restaurant.cuisine_type}")
restaurant.describe_restaurant()
restaurant.open_restaurant()

# 9-2 Three Restaurants
restaurant_1 = Restaurant('RR', 'morning food')
restaurant_2 = Restaurant('The Bear', 'Italian')
restaurant_3 = Restaurant('The Cat', 'Japanese')
restaurant_1.describe_restaurant()
restaurant_2.describe_restaurant()
restaurant_3.describe_restaurant()

# 9-3 Users
class User:
    def __init__(self, first_name, last_name, age):
        """Initialize user attributes."""
        self.first_name = first_name
        self.last_name = last_name
        self.age = age

    def describe_user(self):
        """Print a summary of the user's information."""
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}")

    def greet_user(self):
        """Print a personalized greeting to the user."""
        print(f"Hello, {self.first_name} {self.last_name}!")

user_1 = User('Rafaela', 'Passarinho', 27)
user_1.describe_user()
user_1.greet_user()
# Out:
# Restaurant name: RR
# Cuisine type: morning food
# RR serves morning food cuisine.
# RR is now open!
# RR serves morning food cuisine.
# The Bear serves Italian cuisine.
# The Cat serves Japanese cuisine.
# User: Rafaela Passarinho, Age: 27
# Hello, Rafaela Passarinho!

# %% [markdown]
# #### Working with Classes and Instances

# %% [markdown]
# ##### The Car Class

# %%
# car.py
class Car:
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        """Initialize attributes to describe a car."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print(f"This car has {self.odometer_reading} kilometers on it.")
    
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value."""
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, kilometers):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += kilometers
    
my_new_car = Car('BYD', 'dolphin', 2025)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()

my_used_car = Car('fiat', 'uno', 2003)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(174_753)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()
# Out:
# 2025 Byd Dolphin
# This car has 0 kilometers on it.
# 2003 Fiat Uno
# This car has 174753 kilometers on it.
# This car has 174853 kilometers on it.

# %%
# 9-4 Number Served
class Restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        """Initialize restaurant name and cuisine type."""
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        self.number_served = 0
    def describe_restaurant(self):
        """Print a description of the restaurant."""
        print(f"{self.restaurant_name} serves {self.cuisine_type} cuisine.")

    def open_restaurant(self):
        """Print a message indicating that the restaurant is open."""
        print(f"{self.restaurant_name} is now open!")
    
    def set_number_served(self, number):
        """Set the number of customers served."""
        self.number_served = number

    def increment_number_served(self, increment):
        """Increment the number of customers served by a given amount."""
        self.number_served += increment

restaurant = Restaurant('RR', 'morning food')
restaurant.describe_restaurant()
restaurant.open_restaurant()
restaurant.set_number_served(10)
print(f"Number of customers served: {restaurant.number_served}")
restaurant.increment_number_served(5)
print(f"Number of customers served after increment: {restaurant.number_served}")

# 9-5 Login Attempts
class User:
    def __init__(self, first_name, last_name, age):
        """Initialize user attributes."""
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.login_attempts = 0

    def describe_user(self):
        """Print a summary of the user's information."""
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}")

    def greet_user(self):
        """Print a personalized greeting to the user."""
        print(f"Hello, {self.first_name} {self.last_name}!")

    def increment_login_attempts(self):
        """Increment the number of login attempts by 1."""
        self.login_attempts += 1
    
    def reset_login_attempts(self):
        """Reset the number of login attempts to 0."""
        self.login_attempts = 0
    
user_1 = User('Rafaela', 'Passarinho', 27)
user_1.describe_user()
user_1.greet_user()
user_1.increment_login_attempts()
user_1.increment_login_attempts()
print(f"Login attempts: {user_1.login_attempts}")
user_1.reset_login_attempts()
print(f"Login attempts after reset: {user_1.login_attempts}")
# Out:
# RR serves morning food cuisine.
# RR is now open!
# Number of customers served: 10
# Number of customers served after increment: 15
# User: Rafaela Passarinho, Age: 27
# Hello, Rafaela Passarinho!
# Login attempts: 2
# Login attempts after reset: 0

# %% [markdown]
# #### Inheritance

# %%
# eletric_car.py
class Car:
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        """Initialize attributes to describe a car."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print(f"This car has {self.odometer_reading} kilometers on it.")
    
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value."""
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, kilometers):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += kilometers

class Batery:
    """A simple attempt to model a battery for an electric car."""
    def __init__(self, batery_size=75):
        """Initialize the battery's attributes."""
        self.batery_size = batery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print(f"This car has a {self.batery_size}-kWh battery.")
    
    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.batery_size == 75:
            range = 260
        elif self.batery_size == 100:
            range = 315
        message = f"This car can go approximately {range} kilometers on a full charge."
        print(message)

class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    def __init__(self, make, model, year):
        """Initialize attributes of the parent class."""
        super().__init__(make, model, year)
        self.battery = Batery()
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print(f"This car has a {self.battery_size}-kWh battery.")
    
    def fill_gas_tank(self):
        """Electric cars don't have gas tanks."""
        print("This car doesn't need a gas tank!")

my_byd = ElectricCar('BYD', 'dolphin', 2025)
print(my_byd.get_descriptive_name())
my_byd.battery.describe_battery()
my_byd.battery.get_range()
# Out:
# 2025 Byd Dolphin
# This car has a 75-kWh battery.
# This car can go approximately 260 kilometers on a full charge.

# %%
# 9-6 Ice Cream Stand
class IceCreamStand(Restaurant):
    """Represent aspects of a restaurant, specific to an ice cream stand."""
    def __init__(self, restaurant_name, cuisine_type='ice cream'):
        """Initialize attributes of the parent class."""
        super().__init__(restaurant_name, cuisine_type)
        self.flavors = []

    def display_flavors(self):
        """Display the available ice cream flavors."""
        if self.flavors:
            print(f"{self.restaurant_name} offers the following flavors:")
            for flavor in self.flavors:
                print(f"- {flavor}")
        else:
            print(f"{self.restaurant_name} has no flavors available at the moment.")

my_ice_cream_stand = IceCreamStand('Beijo Frio')
my_ice_cream_stand.display_flavors()

# 9-8 Privileges
class Privileges:
    """A class to store privileges for an admin."""
    def __init__(self):
        """Initialize the privileges attribute."""
        self.privileges = ['can add post', 'can delete post', 'can ban user']
    def show_privileges(self):
        """Display the admin's set of privileges."""
        print("Admin privileges:")
        for privilege in self.privileges:
            print(f"- {privilege}")

# 9-7 Admin
class Admin(User):
    """A user with administrative privileges."""
    def __init__(self, first_name, last_name, age):
        """Initialize attributes of the parent class."""
        super().__init__(first_name, last_name, age)
        self.privileges = Privileges()
    

admin_user = Admin('Rafaela', 'Passarinho', 27)
admin_user.describe_user()

new_admin = Admin('Rafaela', 'Passarinho', 27)
new_admin.describe_user()
new_admin.privileges.show_privileges()

# 9-9 Battery Upgrade
class Car:
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        """Initialize attributes to describe a car."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print(f"This car has {self.odometer_reading} kilometers on it.")
    
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value."""
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, kilometers):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += kilometers

class Batery:
    """A simple attempt to model a battery for an electric car."""
    def __init__(self, batery_size=75):
        """Initialize the battery's attributes."""
        self.batery_size = batery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print(f"This car has a {self.batery_size}-kWh battery.")
    
    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.batery_size == 75:
            range = 260
        elif self.batery_size == 100:
            range = 315
        message = f"This car can go approximately {range} kilometers on a full charge."
        print(message)
    
    def upgrade_battery(self):
        """Upgrade the battery to a larger size if it is not already upgraded."""
        if self.batery_size != 100:
            self.batery_size = 100
            print("Battery upgraded to 100 kWh.")


class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    def __init__(self, make, model, year):
        """Initialize attributes of the parent class."""
        super().__init__(make, model, year)
        self.battery = Batery()
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print(f"This car has a {self.battery_size}-kWh battery.")
    
    def fill_gas_tank(self):
        """Electric cars don't have gas tanks."""
        print("This car doesn't need a gas tank!")

my_byd = ElectricCar('BYD', 'dolphin', 2025)
print(my_byd.get_descriptive_name())
my_byd.battery.describe_battery()
my_byd.battery.get_range()
my_byd.battery.upgrade_battery()
my_byd.battery.describe_battery()
my_byd.battery.get_range()
# Out:
# Beijo Frio has no flavors available at the moment.
# User: Rafaela Passarinho, Age: 27
# User: Rafaela Passarinho, Age: 27
# Admin privileges:
# - can add post
# - can delete post
# - can ban user
# 2025 Byd Dolphin
# This car has a 75-kWh battery.
# This car can go approximately 260 kilometers on a full charge.
# Battery upgraded to 100 kWh.
# This car has a 100-kWh battery.
# This car can go approximately 315 kilometers on a full charge.

# %% [markdown]
# #### Importing Classes

# %%
from car import Car

my_new_car = Car('BYD', 'dolphin', 2025)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()
my_new_car.update_odometer(23_500)
my_new_car.read_odometer()
my_new_car.increment_odometer(100)
my_new_car.read_odometer()
# Out:
# 2025 Byd Dolphin
# This car has 0 kilometers on it.
# This car has 23500 kilometers on it.
# This car has 23600 kilometers on it.

# %%
from car import ElectricCar

my_byd = ElectricCar('BYD', 'dolphin', 2025)
print(my_byd.get_descriptive_name())
my_byd.battery.describe_battery()
my_byd.battery.get_range()
# Out:
# 2025 Byd Dolphin
# This car has a 75-kWh battery.
# This car can go approximately 260 kilometers on a full charge.

# %%
from car import Car, ElectricCar

my_uno = Car('Fiat', 'Uno', 2003)
print(my_uno.get_descriptive_name())
my_uno.read_odometer()
my_uno.update_odometer(174_753)
my_uno.read_odometer()
my_uno.increment_odometer(100)
my_uno.read_odometer()

my_byd = ElectricCar('BYD', 'dolphin', 2025)
print(my_byd.get_descriptive_name())
my_byd.battery.describe_battery()
my_byd.battery.get_range()
my_byd.battery.upgrade_battery()
my_byd.battery.describe_battery()
my_byd.battery.get_range()
# Out:
# 2003 Fiat Uno
# This car has 0 kilometers on it.
# This car has 174753 kilometers on it.
# This car has 174853 kilometers on it.
# 2025 Byd Dolphin
# This car has a 75-kWh battery.
# This car can go approximately 260 kilometers on a full charge.
# Battery upgraded to 100 kWh.
# This car has a 100-kWh battery.
# This car can go approximately 315 kilometers on a full charge.
